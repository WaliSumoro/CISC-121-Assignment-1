# %% [markdown]
# Your Name:Walelign Sumoro
#
# Section: CISC 121
#
# ID: 20476619
#
# Github Link of this notebook:

# %% [markdown]
# 1) Understanding & Breakdown
#
# I reverse a string using recursion. Base case is an empty or one-character string. I combine the reverse of the tail with the head. Time is O(n) and space is O(n) due to recursion depth.

# %% [markdown]
# Here is my draft psudocode

# %%
FUNCTION reverse_str_draft(s):
    RETURN s[::-1]     // WRONG: slicing is not recursion (doesn't meet the requirement)
END FUNCTION

# %% [markdown]
# 2) Peer Review & Draft Code
#
# I checked standard recursive solutions for reversing strings. My draft used slicing which is not recursion and misses the point of the exercise.
# Here is the solution that i checked on leetcode:https://leetcode.com/problems/reverse-string/solutions/7158433/clear-simple-beginner-friendly-100-efficient-easily-explained/

# %% [markdown]
# Here is my draft code

# %%
def reverse_str_draft(s: str) -> str:
    return s[::-1]   # WRONG per recursion requirement

# %% [markdown]
# Here is also the refined code by ChatGPT

# %%
def reverse_str(s: str) -> str:
    """
    Reverse a string using recursion.
    """
    if len(s) <= 1:
        return s
    return reverse_str(s[1:]) + s[0]

# quick checks
assert reverse_str("") == ""
assert reverse_str("a") == "a"
assert reverse_str("abc") == "cba"
assert reverse_str("racecar") == "racecar"

# %% [markdown]
# 4) Review & Fixes
#
# Fix 1: Replaced slicing shortcut with real recursion.
# Fix 2: Added base case len(s) <= 1 to stop.
# Fix 3: Added tests for empty, single, palindromes, and normal strings.

# %% [markdown]
# 5) Reflection on Your Contribution
#
# AI nudged me to use pure recursion instead of a Python shortcut. I implemented the recursive definition and verified it with small tests.
